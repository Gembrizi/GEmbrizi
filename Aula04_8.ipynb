# %% [markdown]
# <a href="https://colab.research.google.com/github/Gembrizi/GEmbrizi/blob/main/Aula04_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exercicio 05 AulaLP02)
# #na parte explicativo, o hashtag é um simbulo em linguagem MARKDOWN usado para formatar TITULO

# %%
P=float(input("!Digite valor em polegas:"))
mm = P * 25.4
print(mm)
# Out:
# !Digite valor em polegas:2
# 50.8

# %%
from math import pi
#vou solicitar inicialmente o raio
raio = float(input("Digite o raio:"))
v = (4/3) * pi * raio**3
print (v)
# Out:
# Digite o raio:2
# 33.510321638291124
